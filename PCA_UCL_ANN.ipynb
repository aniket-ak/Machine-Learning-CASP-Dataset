# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aniket-cfd/machine_learning_exercies/blob/master/.ipynb_checkpoints/ANN%20for%20MNIST-checkpoint.ipynb)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.metrics import r2_score
def plot_results(X, y, lin_reg_model, name):
    plt.figure(figsize=(10,6))
    y_pred = lin_reg_model.predict(X)
    plt.scatter(y_pred,y, alpha=0.2)
    plt.plot([y_pred.min(),y_pred.max()],[y.min(),y.max()],'k')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title("R2 Score = " +str(r2_score(lin_reg_model.predict(X), y)))
    plt.savefig(name+'.svg', format='svg')

# %%
casp = pd.read_csv("CASP.csv")
casp.head()
# Out:
#      RMSD        F1       F2       F3        F4            F5        F6  \
# 0  17.284  13558.30  4305.35  0.31754  162.1730  1.872791e+06  215.3590
# 1   6.021   6191.96  1623.16  0.26213   53.3894  8.034467e+05   87.2024
# 2   9.275   7725.98  1726.28  0.22343   67.2887  1.075648e+06   81.7913
# 3  15.851   8424.58  2368.25  0.28111   67.8325  1.210472e+06  109.4390
# 4   7.962   7460.84  1736.94  0.23280   52.4123  1.021020e+06   94.5234
#
#         F7   F8       F9
# 0  4287.87  102  27.0302
# 1  3328.91   39  38.5468
# 2  2981.04   29  38.8119
# 3  3248.22   70  39.0651
# 4  2814.42   41  39.9147

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

scaler_pipeline = Pipeline([
    ("minmax_scaler", MinMaxScaler()),
#     ("pca", PCA(n_components=0.99))
])
casp_scaled = scaler_pipeline.fit_transform(casp)

from sklearn.model_selection import train_test_split

X_train_full, X_test, y_train_full, y_test = train_test_split(casp_scaled[:,1:],casp_scaled[:,0], test_size=0.3, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.3, random_state=42)

# %%
pd.DataFrame(np.column_stack([y_train, X_train])).hist(bins=50, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb301ad090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb4c8c6550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb30357f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb2fe71e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb30278d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb30200490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb2fe32790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb492b8a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb2f263650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb302c59d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb2d401410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbb49ecc690>]],
#       dtype=object)

# %%
model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=X_train[0,:].shape))
model.add(keras.layers.Dense(750, activation='relu'))
model.add(keras.layers.Dense(500, activation='relu'))
model.add(keras.layers.Dense(250, activation='relu'))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(50, activation='relu'))
model.add(keras.layers.Dense(10, activation='relu'))
model.add(keras.layers.Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 750)               4500
# _________________________________________________________________
# dense_41 (Dense)             (None, 500)               375500
# _________________________________________________________________
# dense_42 (Dense)             (None, 250)               125250
# _________________________________________________________________
# dense_43 (Dense)             (None, 100)               25100
# _________________________________________________________________
# dense_44 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_45 (Dense)             (None, 10)                510
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 535,921
# Trainable params: 535,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=0.03))

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("casp.h5", save_best_only=True)

# %%
history = model.fit(X_train, y_train, epochs=1000, 
                   validation_data=(X_valid, y_valid),
                   callbacks=[checkpoint_cb])
# Out:
# Epoch 1/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0230 - val_loss: 0.0276
# Epoch 2/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0229 - val_loss: 0.0396
# Epoch 3/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0229 - val_loss: 0.0308
# Epoch 4/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0229 - val_loss: 0.0246
# Epoch 5/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0227 - val_loss: 0.0287
# Epoch 6/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0229 - val_loss: 0.0246
# Epoch 7/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0228 - val_loss: 0.0242
# Epoch 8/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0230 - val_loss: 0.0250
# Epoch 9/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0228 - val_loss: 0.0256
# Epoch 10/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0228 - val_loss: 0.0248
# Epoch 11/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0228 - val_loss: 0.0300
# Epoch 12/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0228 - val_loss: 0.0318
# Epoch 13/1000
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0227 - val_loss: 0.0318
# Epoch 14/1000
# 701/701 [==============================] - 5s 8ms/step - loss: 0.0226 - val_loss: 0.0243
# Epoch 15/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0226 - val_loss: 0.0261
# Epoch 16/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0226 - val_loss: 0.0258
# Epoch 17/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0228 - val_loss: 0.0295
# Epoch 18/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0225 - val_loss: 0.0262
# Epoch 19/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0225 - val_loss: 0.0244
# Epoch 20/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0222 - val_loss: 0.0298
# Epoch 21/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0222 - val_loss: 0.0287
# Epoch 22/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0223 - val_loss: 0.0251
# Epoch 23/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0223 - val_loss: 0.0299
# Epoch 24/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0223 - val_loss: 0.0272
# Epoch 25/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0222 - val_loss: 0.0254
# Epoch 26/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0221 - val_loss: 0.0236
# Epoch 27/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0221 - val_loss: 0.0505
# Epoch 28/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0220 - val_loss: 0.0278
# Epoch 29/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0221 - val_loss: 0.0245
# Epoch 30/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0221 - val_loss: 0.0251
# Epoch 31/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0223 - val_loss: 0.0251
# Epoch 32/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0220 - val_loss: 0.0271
# Epoch 33/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0218 - val_loss: 0.0241
# Epoch 34/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0220 - val_loss: 0.0243
# Epoch 35/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0218 - val_loss: 0.0251
# Epoch 36/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0218 - val_loss: 0.0242
# Epoch 37/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0219 - val_loss: 0.0256
# Epoch 38/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0220 - val_loss: 0.0245
# Epoch 39/1000
# 701/701 [==============================] - 5s 6ms/step - loss: 0.0217 - val_loss: 0.0254
# Epoch 40/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0219 - val_loss: 0.0404
# Epoch 41/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0219 - val_loss: 0.0278
# Epoch 42/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0218 - val_loss: 0.0252
# Epoch 43/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0218 - val_loss: 0.0241
# Epoch 44/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0217 - val_loss: 0.0245
# Epoch 45/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0215 - val_loss: 0.0257
# Epoch 46/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0213 - val_loss: 0.0255
# Epoch 47/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0216 - val_loss: 0.0249
# Epoch 48/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0214 - val_loss: 0.0243
# Epoch 49/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0216 - val_loss: 0.0260
# Epoch 50/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0217 - val_loss: 0.0244
# Epoch 51/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0215 - val_loss: 0.0246
# Epoch 52/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0213 - val_loss: 0.0293
# Epoch 53/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0216 - val_loss: 0.0261
# Epoch 54/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0217 - val_loss: 0.0311
# Epoch 55/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0214 - val_loss: 0.0251
# Epoch 56/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0213 - val_loss: 0.0344
# Epoch 57/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0213 - val_loss: 0.0350
# Epoch 58/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0215 - val_loss: 0.0302
# Epoch 59/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0212 - val_loss: 0.0301
# Epoch 60/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0212 - val_loss: 0.0248
# Epoch 61/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0212 - val_loss: 0.0276
# Epoch 62/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0211 - val_loss: 0.0272
# Epoch 63/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0211 - val_loss: 0.0236
# Epoch 64/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0212 - val_loss: 0.0243
# Epoch 65/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0210 - val_loss: 0.0243
# Epoch 66/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0212 - val_loss: 0.0252
# Epoch 67/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0209 - val_loss: 0.0261
# Epoch 68/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0210 - val_loss: 0.0257
# Epoch 69/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0210 - val_loss: 0.0237
# Epoch 70/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0211 - val_loss: 0.0239
# Epoch 71/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0212 - val_loss: 0.0312
# Epoch 72/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0210 - val_loss: 0.0449
# Epoch 73/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0212 - val_loss: 0.0274
# Epoch 74/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0207 - val_loss: 0.0320
# Epoch 75/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0209 - val_loss: 0.0265
# Epoch 76/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0210 - val_loss: 0.0244
# Epoch 77/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0209 - val_loss: 0.0334
# Epoch 78/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0210 - val_loss: 0.0262
# Epoch 79/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0209 - val_loss: 0.0272
# Epoch 80/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0208 - val_loss: 0.0237
# Epoch 81/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0207 - val_loss: 0.0256
# Epoch 82/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0205 - val_loss: 0.0242
# Epoch 83/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0207 - val_loss: 0.0242
# Epoch 84/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0206 - val_loss: 0.0254
# Epoch 85/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0206 - val_loss: 0.0232
# Epoch 86/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0205 - val_loss: 0.0335
# Epoch 87/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0206 - val_loss: 0.0271
# Epoch 88/1000
# 701/701 [==============================] - 5s 8ms/step - loss: 0.0205 - val_loss: 0.0235
# Epoch 89/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0204 - val_loss: 0.0346
# Epoch 90/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0204 - val_loss: 0.0240
# Epoch 91/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0204 - val_loss: 0.0248
# Epoch 92/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0204 - val_loss: 0.0234
# Epoch 93/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0205 - val_loss: 0.0237
# Epoch 94/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0206 - val_loss: 0.0234
# Epoch 95/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0205 - val_loss: 0.0343
# Epoch 96/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0204 - val_loss: 0.0303
# Epoch 97/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0206 - val_loss: 0.0238
# Epoch 98/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0203 - val_loss: 0.0236
# Epoch 99/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0203 - val_loss: 0.0255
# Epoch 100/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0204 - val_loss: 0.0242
# Epoch 101/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0202 - val_loss: 0.0234
# Epoch 102/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0203 - val_loss: 0.0248
# Epoch 103/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0204 - val_loss: 0.0255
# Epoch 104/1000
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0204 - val_loss: 0.0245
# Epoch 105/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0204 - val_loss: 0.0453
# Epoch 106/1000
# 701/701 [==============================] - 5s 6ms/step - loss: 0.0202 - val_loss: 0.0231
# Epoch 107/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0202 - val_loss: 0.0252
# Epoch 108/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0200 - val_loss: 0.0232
# Epoch 109/1000
# 701/701 [==============================] - 7s 11ms/step - loss: 0.0201 - val_loss: 0.0264
# Epoch 110/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0199 - val_loss: 0.0253
# Epoch 111/1000
# 701/701 [==============================] - 5s 8ms/step - loss: 0.0201 - val_loss: 0.0228
# Epoch 112/1000
# 701/701 [==============================] - 5s 6ms/step - loss: 0.0203 - val_loss: 0.0245
# Epoch 113/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0200 - val_loss: 0.0345
# Epoch 114/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0200 - val_loss: 0.0229
# Epoch 115/1000
# 701/701 [==============================] - 5s 8ms/step - loss: 0.0200 - val_loss: 0.0268
# Epoch 116/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0198 - val_loss: 0.0307
# Epoch 117/1000
# 701/701 [==============================] - 5s 6ms/step - loss: 0.0200 - val_loss: 0.0270
# Epoch 118/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0198 - val_loss: 0.0238
# Epoch 119/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0198 - val_loss: 0.0250
# Epoch 120/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0200 - val_loss: 0.0236
# Epoch 121/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0198 - val_loss: 0.0249
# Epoch 122/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0199 - val_loss: 0.0259
# Epoch 123/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0200 - val_loss: 0.0287
# Epoch 124/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0199 - val_loss: 0.0237
# Epoch 125/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0197 - val_loss: 0.0235
# Epoch 126/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0200 - val_loss: 0.0237
# Epoch 127/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0197 - val_loss: 0.0256
# Epoch 128/1000
# 701/701 [==============================] - 5s 6ms/step - loss: 0.0198 - val_loss: 0.0241
# Epoch 129/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0198 - val_loss: 0.0242
# Epoch 130/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0198 - val_loss: 0.0250
# Epoch 131/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0196 - val_loss: 0.0242
# Epoch 132/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0197 - val_loss: 0.0239
# Epoch 133/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0196 - val_loss: 0.0300
# Epoch 134/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0196 - val_loss: 0.0286
# Epoch 135/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0196 - val_loss: 0.0272
# Epoch 136/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0195 - val_loss: 0.0258
# Epoch 137/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0197 - val_loss: 0.0250
# Epoch 138/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0195 - val_loss: 0.0229
# Epoch 139/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0193 - val_loss: 0.0229
# Epoch 140/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0195 - val_loss: 0.3694
# Epoch 141/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0205 - val_loss: 0.0364
# Epoch 142/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0194 - val_loss: 0.0265
# Epoch 143/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0194 - val_loss: 0.0338
# Epoch 144/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0193 - val_loss: 0.0249
# Epoch 145/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0194 - val_loss: 0.0312
# Epoch 146/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0193 - val_loss: 0.0253
# Epoch 147/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0192 - val_loss: 0.0276
# Epoch 148/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0194 - val_loss: 0.0237
# Epoch 149/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0192 - val_loss: 0.0249
# Epoch 150/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0193 - val_loss: 0.0239
# Epoch 151/1000
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0193 - val_loss: 0.0258
# Epoch 152/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0192 - val_loss: 0.0242
# Epoch 153/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0192 - val_loss: 0.0252
# Epoch 154/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0193 - val_loss: 0.0256
# Epoch 155/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0191 - val_loss: 0.0244
# Epoch 156/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0191 - val_loss: 0.0241
# Epoch 157/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0193 - val_loss: 0.0237
# Epoch 158/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0194 - val_loss: 0.0241
# Epoch 159/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0192 - val_loss: 0.0310
# Epoch 160/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0191 - val_loss: 0.0454
# Epoch 161/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0192 - val_loss: 0.0242
# Epoch 162/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0191 - val_loss: 0.0230
# Epoch 163/1000
# 701/701 [==============================] - 5s 6ms/step - loss: 0.0189 - val_loss: 0.0234
# Epoch 164/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0191 - val_loss: 0.0249
# Epoch 165/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0188 - val_loss: 0.0254
# Epoch 166/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0190 - val_loss: 0.0231
# Epoch 167/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0190 - val_loss: 0.0231
# Epoch 168/1000
# 701/701 [==============================] - 5s 8ms/step - loss: 0.0189 - val_loss: 0.0241
# Epoch 169/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0187 - val_loss: 0.0245
# Epoch 170/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0190 - val_loss: 0.0234
# Epoch 171/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0188 - val_loss: 0.0243
# Epoch 172/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0188 - val_loss: 0.0235
# Epoch 173/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0191 - val_loss: 0.0229
# Epoch 174/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0187 - val_loss: 0.1217
# Epoch 175/1000
# 701/701 [==============================] - 3s 5ms/step - loss: 0.0188 - val_loss: 0.0359
# Epoch 176/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0190 - val_loss: 0.0256
# Epoch 177/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0187 - val_loss: 0.0229
# Epoch 178/1000
# 701/701 [==============================] - 3s 5ms/step - loss: 0.0188 - val_loss: 0.0230
# Epoch 179/1000
# 701/701 [==============================] - 4s 5ms/step - loss: 0.0188 - val_loss: 0.0237
# Epoch 180/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0189 - val_loss: 0.0239
# Epoch 181/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0188 - val_loss: 0.0340
# Epoch 182/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0187 - val_loss: 0.0231
# Epoch 183/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0187 - val_loss: 0.0278
# Epoch 184/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0185 - val_loss: 0.0332
# Epoch 185/1000
# 701/701 [==============================] - 5s 8ms/step - loss: 0.0185 - val_loss: 0.0230
# Epoch 186/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0185 - val_loss: 0.0251
# Epoch 187/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0188 - val_loss: 0.0249
# Epoch 188/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0184 - val_loss: 0.0227
# Epoch 189/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0184 - val_loss: 0.0262
# Epoch 190/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0185 - val_loss: 0.0245
# Epoch 191/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0186 - val_loss: 0.0235
# Epoch 192/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0185 - val_loss: 0.0234
# Epoch 193/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0186 - val_loss: 0.0233
# Epoch 194/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0184 - val_loss: 0.0229
# Epoch 195/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0184 - val_loss: 0.0280
# Epoch 196/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0183 - val_loss: 0.0341
# Epoch 197/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0184 - val_loss: 0.0228
# Epoch 198/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0185 - val_loss: 0.0237
# Epoch 199/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0185 - val_loss: 0.0231
# Epoch 200/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0184 - val_loss: 0.0240
# Epoch 201/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0184 - val_loss: 0.0224
# Epoch 202/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0184 - val_loss: 0.0238
# Epoch 203/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0184 - val_loss: 0.0238
# Epoch 204/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0181 - val_loss: 0.0236
# Epoch 205/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0183 - val_loss: 0.0238
# Epoch 206/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0182 - val_loss: 0.0384
# Epoch 207/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0184 - val_loss: 0.0233
# Epoch 208/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0183 - val_loss: 0.0238
# Epoch 209/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0184 - val_loss: 0.0235
# Epoch 210/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0180 - val_loss: 0.0249
# Epoch 211/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0181 - val_loss: 0.0234
# Epoch 212/1000
# 701/701 [==============================] - 5s 8ms/step - loss: 0.0181 - val_loss: 0.0253
# Epoch 213/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0182 - val_loss: 0.0234
# Epoch 214/1000
# 701/701 [==============================] - 5s 6ms/step - loss: 0.0183 - val_loss: 0.0244
# Epoch 215/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0181 - val_loss: 0.0233
# Epoch 216/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0180 - val_loss: 0.0229
# Epoch 217/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0182 - val_loss: 0.0239
# Epoch 218/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0181 - val_loss: 0.0234
# Epoch 219/1000
# 701/701 [==============================] - 6s 8ms/step - loss: 0.0180 - val_loss: 0.0286
# Epoch 220/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0180 - val_loss: 0.0246
# Epoch 221/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0181 - val_loss: 0.0236
# Epoch 222/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0181 - val_loss: 0.0232
# Epoch 223/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0179 - val_loss: 0.0242
# Epoch 224/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0181 - val_loss: 0.0243
# Epoch 225/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0179 - val_loss: 0.0242
# Epoch 226/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0179 - val_loss: 0.0276
# Epoch 227/1000
# 701/701 [==============================] - 5s 7ms/step - loss: 0.0180 - val_loss: 0.0241
# Epoch 228/1000
# 701/701 [==============================] - 4s 6ms/step - loss: 0.0179 - val_loss: 0.0247
# Epoch 229/1000
# 359/701 [==============>...............] - ETA: 1s - loss: 0.0177
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-3c6ae5a96aab> in <module>
#       1 history = model.fit(X_train, y_train, epochs=1000,
#       2                    validation_data=(X_valid, y_valid),
# ----> 3                    callbacks=[checkpoint_cb])
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))

# %%
plot_results(X_train, y_train, model, "ANN")

# %%
plot_results(X_test, y_test, model, "ANN_test")
